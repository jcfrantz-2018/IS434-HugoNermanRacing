# %%
from datetime import datetime
from itertools import dropwhile, takewhile

import instaloader
import json
import ast

import os
import pandas as pd
from glob import glob
import orjson

###################################################################
#---------Below Code is used to scrape Instagram posts-----------##
###################################################################

# L = instaloader.Instaloader()

# USER = '' #Instagram Username
# PASSWORD = '' #Instagram Password
# L.login(USER, PASSWORD)

# posts = instaloader.Profile.from_username(L.context, "hugonerman").get_posts()

# # Tracing backwards from today
# SINCE = datetime(2022, 2, 28) # February 22, 2022
# UNTIL = datetime(2016, 1, 22) # January 22, 2022

# for post in takewhile(lambda p: p.date > UNTIL, dropwhile(lambda p: p.date > SINCE, posts)):
#     print(post.date)
#     L.download_post(post, "hugonerman")

# %%
# Retrieve metadata from posts

def parse_instafiles(path):

    os.chdir(path)
    
    dataframe = pd.DataFrame(columns=[])
        
    glob('*UTC.json')
    
    for file in glob('*UTC.json'):
        with open(file, 'r') as filecontent:
            filename = filecontent.name[:-5]

            try:
                metadata = orjson.loads(filecontent.read())
            
            except IOError as e:
                print("I/O Error. Couldn't load file. Trying the next one...")
                continue
            else:
                pass
            username = metadata['node']['owner']['username']
            image = metadata['node']['display_url']
            time = datetime.fromtimestamp(int(metadata['node']['taken_at_timestamp']))
            likes = int(metadata['node']['edge_media_preview_like']['count'])   
            
            
            try:
                text = metadata['node']['edge_media_to_caption']['edges'][0]['node']['text']
            except:
                text = ""
            try:
                post_id = metadata['node']['id']
            except:
                post_id = ""
            minedata = {'filename': filename, "username": username, 'time': time, 'text': text,
                    'likes': likes, 'post_id' : post_id, 'image_url':image}
            dataframe = dataframe.append(minedata, ignore_index=True)
            del metadata
            filecontent.close()
    return dataframe

# %%
# Windows OS path (if error, then manually set to your path)
metadata_path = os.getcwd() + '\hugo nerman image metadata - 2 YEARS'

df_instagram = parse_instafiles(metadata_path)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_68744\2206320443.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(minedata, ignore_index=True)

# %%
df_instagram.head()
# Out:
#                   filename    username                time  \
# 0  2020-02-08_18-40-31_UTC  hugonerman 2020-02-09 02:40:31
# 1  2020-02-09_15-52-32_UTC  hugonerman 2020-02-09 23:52:32
# 2  2020-02-11_18-13-24_UTC  hugonerman 2020-02-12 02:13:24
# 3  2020-02-15_17-10-39_UTC  hugonerman 2020-02-16 01:10:39
# 4  2020-02-19_17-07-47_UTC  hugonerman 2020-02-20 01:07:47
#
#                                                 text  likes  \
# 0  Kicking of the 2020 season in Åre💥 Great days ...   1170
# 1  ”Turn right to go left” - Doc Hudson🌅\n📸@armin...    860
# 2  White, Red or Black?⚪️🔴⚫️\n📸@arminiiius\n.\n#p...    705
# 3  Fire on Ice🔥\n📸@arminiiius\n.\n#porsche911 #fl...   1008
# 4  Hugo and @Boss 🐧\n📸@arminiiius\n.\n#hugoboss #...   1131
#
#                post_id                                          image_url
# 0  2239483275792155206  https://instagram.fsin8-2.fna.fbcdn.net/v/t51....
# 1  2240123502097432468  https://instagram.fsin8-2.fna.fbcdn.net/v/t51....
# 2  2241643952036194348  https://instagram.fsin8-2.fna.fbcdn.net/v/t51....
# 3  2244511467297038385  https://instagram.fsin8-2.fna.fbcdn.net/v/t51....
# 4  2247409134662523334  https://instagram.fsin8-2.fna.fbcdn.net/v/t51....

# %%
df_instagram.drop(['username','time','text','post_id','image_url'], axis='columns', inplace=True)
df_instagram
# Out:
#                     filename  likes
# 0    2020-02-08_18-40-31_UTC   1170
# 1    2020-02-09_15-52-32_UTC    860
# 2    2020-02-11_18-13-24_UTC    705
# 3    2020-02-15_17-10-39_UTC   1008
# 4    2020-02-19_17-07-47_UTC   1131
# ..                       ...    ...
# 120  2021-08-23_16-36-47_UTC   1986
# 121  2021-08-30_20-44-59_UTC   1211
# 122  2021-10-07_18-45-29_UTC   2207
# 123  2021-12-24_23-21-59_UTC   1233
# 124  2022-01-10_08-01-21_UTC   1470
#
# [125 rows x 2 columns]

# %%
instagram_likes = list(df_instagram['likes'])
print(len(instagram_likes))
# Out:
# 125

# %%
os.chdir(os.path.normpath(os.getcwd() + os.sep + os.pardir))
df_rekognition = pd.read_csv('rekognition_output - 2 YEARS.csv')
df_rekognition
# Out:
#                                FileName  \
# 0    2020-02-08_18-40-31_UTC_1.jpg.json
# 1    2020-02-08_18-40-31_UTC_2.jpg.json
# 2    2020-02-08_18-40-31_UTC_3.jpg.json
# 3    2020-02-08_18-40-31_UTC_4.jpg.json
# 4    2020-02-08_18-40-31_UTC_5.jpg.json
# ..                                  ...
# 203  2021-08-23_16-36-47_UTC_3.jpg.json
# 204    2021-08-30_20-44-59_UTC.jpg.json
# 205    2021-10-07_18-45-29_UTC.jpg.json
# 206    2021-12-24_23-21-59_UTC.jpg.json
# 207    2022-01-10_08-01-21_UTC.jpg.json
#
#                                      Rekognition_words
# 0    ['Car', 'Automobile', 'Vehicle', 'Transportati...
# 1    ['Car', 'Automobile', 'Vehicle', 'Transportati...
# 2    ['Clothing', 'Apparel', 'Person', 'Human', 'Ja...
# 3    ['Sports Car', 'Car', 'Vehicle', 'Transportati...
# 4    ['Person', 'Human', 'Sports Car', 'Car', 'Vehi...
# ..                                                 ...
# 203  ['Race Car', 'Sports Car', 'Car', 'Vehicle', '...
# 204  ['Race Car', 'Car', 'Sports Car', 'Transportat...
# 205  ['Race Car', 'Sports Car', 'Car', 'Vehicle', '...
# 206  ['Car', 'Transportation', 'Vehicle', 'Automobi...
# 207  ['Cushion', 'Person', 'Human', 'Car Seat', 'Ca...
#
# [208 rows x 2 columns]

# %%
new_filenames = df_rekognition['FileName']
# print(new_filenames)

# %%
new_list = []
for file in new_filenames:
    filenames = file.split('.', 1)
    appended_filename = filenames[0]
    new_list.append(appended_filename)
    
new_list2 = []
for ch in new_list:
    if ch[-1] != 'C':
        new_str = ch[0:-2]
        new_list2.append(new_str)
    else:
        new_list2.append(ch)
        
# print(new_list2)

# %%
rekog_words_temp = list(df_rekognition['Rekognition_words'])
rekog_words = []

for words in rekog_words_temp:
    formatted_words = ast.literal_eval(words)
    rekog_words.append(formatted_words)

# %%
new_df = pd.DataFrame(list(zip(new_list2, rekog_words)), columns=['FileName','Rekognition_words'])
new_df
# Out:
#                     FileName  \
# 0    2020-02-08_18-40-31_UTC
# 1    2020-02-08_18-40-31_UTC
# 2    2020-02-08_18-40-31_UTC
# 3    2020-02-08_18-40-31_UTC
# 4    2020-02-08_18-40-31_UTC
# ..                       ...
# 203  2021-08-23_16-36-47_UTC
# 204  2021-08-30_20-44-59_UTC
# 205  2021-10-07_18-45-29_UTC
# 206  2021-12-24_23-21-59_UTC
# 207  2022-01-10_08-01-21_UTC
#
#                                      Rekognition_words
# 0    [Car, Automobile, Vehicle, Transportation, Spo...
# 1    [Car, Automobile, Vehicle, Transportation, Nat...
# 2     [Clothing, Apparel, Person, Human, Jacket, Coat]
# 3    [Sports Car, Car, Vehicle, Transportation, Per...
# 4    [Person, Human, Sports Car, Car, Vehicle, Tran...
# ..                                                 ...
# 203  [Race Car, Sports Car, Car, Vehicle, Person, T...
# 204  [Race Car, Car, Sports Car, Transportation, Ve...
# 205  [Race Car, Sports Car, Car, Vehicle, Transport...
# 206  [Car, Transportation, Vehicle, Automobile, Per...
# 207  [Cushion, Person, Human, Car Seat, Car, Transp...
#
# [208 rows x 2 columns]

# %%
aggregation_functions = {'FileName': 'first', 'Rekognition_words': 'sum'}
new_df2 = new_df.groupby(new_df['FileName']).aggregate(aggregation_functions)
new_df2
# Out:
#                                         FileName  \
# FileName
# 2020-02-08_18-40-31_UTC  2020-02-08_18-40-31_UTC
# 2020-02-09_15-52-32_UTC  2020-02-09_15-52-32_UTC
# 2020-02-11_18-13-24_UTC  2020-02-11_18-13-24_UTC
# 2020-02-15_17-10-39_UTC  2020-02-15_17-10-39_UTC
# 2020-02-19_17-07-47_UTC  2020-02-19_17-07-47_UTC
# ...                                          ...
# 2021-08-23_16-36-47_UTC  2021-08-23_16-36-47_UTC
# 2021-08-30_20-44-59_UTC  2021-08-30_20-44-59_UTC
# 2021-10-07_18-45-29_UTC  2021-10-07_18-45-29_UTC
# 2021-12-24_23-21-59_UTC  2021-12-24_23-21-59_UTC
# 2022-01-10_08-01-21_UTC  2022-01-10_08-01-21_UTC
#
#                                                          Rekognition_words
# FileName
# 2020-02-08_18-40-31_UTC  [Car, Automobile, Vehicle, Transportation, Spo...
# 2020-02-09_15-52-32_UTC  [Car, Transportation, Vehicle, Wheel, Tire, Sp...
# 2020-02-11_18-13-24_UTC  [Car, Vehicle, Transportation, Sports Car, Nat...
# 2020-02-15_17-10-39_UTC  [Car, Automobile, Vehicle, Transportation, Bum...
# 2020-02-19_17-07-47_UTC   [Clothing, Apparel, Jacket, Coat, Person, Human]
# ...                                                                    ...
# 2021-08-23_16-36-47_UTC  [Person, Human, Crowd, Text, Press Conference,...
# 2021-08-30_20-44-59_UTC  [Race Car, Car, Sports Car, Transportation, Ve...
# 2021-10-07_18-45-29_UTC  [Race Car, Sports Car, Car, Vehicle, Transport...
# 2021-12-24_23-21-59_UTC  [Car, Transportation, Vehicle, Automobile, Per...
# 2022-01-10_08-01-21_UTC  [Cushion, Person, Human, Car Seat, Car, Transp...
#
# [125 rows x 2 columns]

# %%
rekog_list = list(new_df2['Rekognition_words'])
filename_list = list(new_df2['FileName'])

new_rekog = []

for indiv_list in rekog_list:
    myset = set(indiv_list)
    new_rekog.append(list(myset))

# %%
new_df_rekognition = pd.DataFrame(list(zip(new_list2, instagram_likes, rekog_words)), columns=['FileName','likes','Rekognition_words'])

new_df_rekognition
# Out:
#                     FileName  likes  \
# 0    2020-02-08_18-40-31_UTC   1170
# 1    2020-02-08_18-40-31_UTC    860
# 2    2020-02-08_18-40-31_UTC    705
# 3    2020-02-08_18-40-31_UTC   1008
# 4    2020-02-08_18-40-31_UTC   1131
# ..                       ...    ...
# 120  2020-08-28_19-58-32_UTC   1986
# 121  2020-08-28_19-58-32_UTC   1211
# 122  2020-08-29_10-25-16_UTC   2207
# 123  2020-08-29_17-05-30_UTC   1233
# 124  2020-08-30_08-49-33_UTC   1470
#
#                                      Rekognition_words
# 0    [Car, Automobile, Vehicle, Transportation, Spo...
# 1    [Car, Automobile, Vehicle, Transportation, Nat...
# 2     [Clothing, Apparel, Person, Human, Jacket, Coat]
# 3    [Sports Car, Car, Vehicle, Transportation, Per...
# 4    [Person, Human, Sports Car, Car, Vehicle, Tran...
# ..                                                 ...
# 120  [Car, Automobile, Vehicle, Transportation, Rac...
# 121  [Tarmac, Asphalt, Road, Sports Car, Transporta...
# 122  [Clothing, Apparel, Ninja, Helmet, Person, Human]
# 123  [Race Car, Sports Car, Car, Vehicle, Transport...
# 124  [Car, Automobile, Vehicle, Transportation, Rac...
#
# [125 rows x 3 columns]

# %% [markdown]
# ## Create dictionary with key-value pair of label - likes

# %%
likes = list(new_df_rekognition['likes'])
rekognition_words = list(new_df_rekognition['Rekognition_words'])

word_score_dict = {}

for i in range(len(likes)):
    like_count = likes[i]
    word_list = rekognition_words[i]
    for word in word_list:
        if word in word_score_dict:
            temp_like_count = word_score_dict[word]
            new_like_count = like_count + temp_like_count
            word_score_dict[word] = new_like_count
        else:
            word_score_dict[word] = like_count
            
print(word_score_dict)
# Out:
# {'Car': 159663, 'Automobile': 99656, 'Vehicle': 148615, 'Transportation': 149196, 'Sports Car': 121041, 'Race Car': 94732, 'Offroad': 5821, 'Wheel': 83409, 'Machine': 59969, 'Nature': 7489, 'Outdoors': 8673, 'Snow': 1706, 'Clothing': 37956, 'Apparel': 27261, 'Person': 38179, 'Human': 25502, 'Jacket': 1541, 'Coat': 1541, 'Coupe': 21571, 'Tire': 86051, 'Spoke': 74816, 'Alloy Wheel': 68825, 'Car Wheel': 63251, 'Bird': 800, 'Bumper': 2105, 'Flyer': 796, 'Advertisement': 796, 'Paper': 796, 'Poster': 796, 'Formula One': 12537, 'Car Wash': 1074, 'Winter': 846, 'Light': 2037, 'Tarmac': 36307, 'Asphalt': 24691, 'Hug': 1086, 'Dating': 1086, 'Road': 5258, 'Helmet': 29620, 'Crash Helmet': 17520, 'Water': 1237, 'Sea': 1237, 'Ice': 1237, 'Gravel': 1237, 'Tree': 1237, 'Fir': 1237, 'Sunglasses': 1528, 'Accessories': 2772, 'Accessory': 2772, 'Crowd': 1528, 'Shoe': 3768, 'Footwear': 2784, 'Sneaker': 2784, 'Running Shoe': 894, 'Fire Truck': 826, 'Truck': 826, 'Convertible': 763, 'Lawn Mower': 826, 'People': 3185, 'Football Helmet': 3185, 'Team': 3185, 'Sport': 3185, 'Team Sport': 3185, 'Football': 3185, 'American Football': 1030, 'Dynamite': 1121, 'Weapon': 1121, 'Bomb': 1121, 'Weaponry': 1121, 'Box': 1121, 'Cardboard': 1121, 'Hat': 1681, 'Driving': 1175, 'Goggles': 1244, 'Glasses': 1244, 'Cushion': 1802, 'Kart': 1416, 'Clinic': 3099, 'Doctor': 3099, 'Ninja': 2207}

# %% [markdown]
# ## Create dictionary with key-value pair of label - label occurence

# %%
word_freq_dict_raw = {}
rekognition_words = list(new_df_rekognition['Rekognition_words'])
unique_words_raw = []

# Get words and their number of occurences
for i in range(len(likes)):
    word_list = rekognition_words[i]
    for word in word_list:
        if word in word_freq_dict_raw:
            temp_word_count = word_freq_dict_raw[word]
            new_word_count = temp_word_count + 1
            word_freq_dict_raw[word] = new_word_count
        else:
            word_freq_dict_raw[word] = 1
            unique_words_raw.append(word)

# Remove words occuring less than 5 times
word_freq_dict = {}
unique_words = []

for word in unique_words_raw:
    word_occurence = word_freq_dict_raw[word]
    if word_occurence >= 2:
        word_freq_dict[word] = word_occurence
        unique_words.append(word)

print(unique_words)
print('-' * 30)
print(word_freq_dict)
# Out:
# ['Car', 'Automobile', 'Vehicle', 'Transportation', 'Sports Car', 'Race Car', 'Offroad', 'Wheel', 'Machine', 'Nature', 'Outdoors', 'Snow', 'Clothing', 'Apparel', 'Person', 'Human', 'Jacket', 'Coat', 'Coupe', 'Tire', 'Spoke', 'Alloy Wheel', 'Car Wheel', 'Bumper', 'Formula One', 'Light', 'Tarmac', 'Asphalt', 'Road', 'Helmet', 'Crash Helmet', 'Accessories', 'Accessory', 'Shoe', 'Footwear', 'Sneaker', 'People', 'Football Helmet', 'Team', 'Sport', 'Team Sport', 'Football']
# ------------------------------
# {'Car': 97, 'Automobile': 59, 'Vehicle': 88, 'Transportation': 89, 'Sports Car': 68, 'Race Car': 44, 'Offroad': 5, 'Wheel': 53, 'Machine': 45, 'Nature': 7, 'Outdoors': 8, 'Snow': 2, 'Clothing': 26, 'Apparel': 20, 'Person': 27, 'Human': 19, 'Jacket': 2, 'Coat': 2, 'Coupe': 19, 'Tire': 58, 'Spoke': 49, 'Alloy Wheel': 44, 'Car Wheel': 41, 'Bumper': 2, 'Formula One': 7, 'Light': 2, 'Tarmac': 26, 'Asphalt': 18, 'Road': 5, 'Helmet': 18, 'Crash Helmet': 12, 'Accessories': 2, 'Accessory': 2, 'Shoe': 4, 'Footwear': 3, 'Sneaker': 3, 'People': 2, 'Football Helmet': 2, 'Team': 2, 'Sport': 2, 'Team Sport': 2, 'Football': 2}

# %% [markdown]
# ## Create dictionary containing average likes of each label

# %%
new_word_dict = {}

for word in unique_words:
    score = word_score_dict[word]
    frequency = word_freq_dict[word]
    new_word_dict[word] = score / frequency
    
print(new_word_dict)
# Out:
# {'Car': 1646.0103092783504, 'Automobile': 1689.084745762712, 'Vehicle': 1688.8068181818182, 'Transportation': 1676.3595505617977, 'Sports Car': 1780.014705882353, 'Race Car': 2153.0, 'Offroad': 1164.2, 'Wheel': 1573.754716981132, 'Machine': 1332.6444444444444, 'Nature': 1069.857142857143, 'Outdoors': 1084.125, 'Snow': 853.0, 'Clothing': 1459.8461538461538, 'Apparel': 1363.05, 'Person': 1414.037037037037, 'Human': 1342.2105263157894, 'Jacket': 770.5, 'Coat': 770.5, 'Coupe': 1135.3157894736842, 'Tire': 1483.6379310344828, 'Spoke': 1526.857142857143, 'Alloy Wheel': 1564.2045454545455, 'Car Wheel': 1542.7073170731708, 'Bumper': 1052.5, 'Formula One': 1791.0, 'Light': 1018.5, 'Tarmac': 1396.423076923077, 'Asphalt': 1371.7222222222222, 'Road': 1051.6, 'Helmet': 1645.5555555555557, 'Crash Helmet': 1460.0, 'Accessories': 1386.0, 'Accessory': 1386.0, 'Shoe': 942.0, 'Footwear': 928.0, 'Sneaker': 928.0, 'People': 1592.5, 'Football Helmet': 1592.5, 'Team': 1592.5, 'Sport': 1592.5, 'Team Sport': 1592.5, 'Football': 1592.5}

# %%
# Get Average likes for each word
word_avg_score_df = pd.DataFrame.from_dict(new_word_dict, orient='index', columns=['score'])
sorted_avg_word_score_df = word_avg_score_df.sort_values(by=['score'], ascending=False)

sorted_avg_word_score_df['Avg. Likes'] = sorted_avg_word_score_df['score']
sorted_avg_word_score_df = sorted_avg_word_score_df.drop('score', axis=1)

# Top 10 labels
sorted_avg_word_score_df.head(10) 

######################################################

# Get Sum of Likes for each word
# word_score_df = pd.DataFrame.from_dict(word_score_dict, orient='index', columns=['score'])
# sorted_word_score_df = word_score_df.sort_values(by=['score'], ascending=False)

# # Top 10 labels
# sorted_word_score_df.head(10)
# Out:
#                  Avg. Likes
# Race Car        2153.000000
# Formula One     1791.000000
# Sports Car      1780.014706
# Automobile      1689.084746
# Vehicle         1688.806818
# Transportation  1676.359551
# Car             1646.010309
# Helmet          1645.555556
# Team Sport      1592.500000
# Sport           1592.500000

# %%
sorted_avg_word_score_df.to_csv(path_or_buf='rekognition_label_score_average.csv')
