# %% [markdown]
# #### 1. Importing necessary libraries

# %%
import pandas as pd

# %% [markdown]
# #### 2. Reading the data file into a dataframe and storing inside a variable

# %%
main_df = pd.ExcelFile('HugoTikTokComments.xlsx')
#Display the list of worksheets in the file
len(main_df.sheet_names)
# Out:
# 209

# %%
#Example of data in one of the worksheets in a 2d format
main_df.parse(sheet_name = "2020-09-11")
# Out:
#                                                   Now  \
# 0                                            Post URL
# 1                                  Publisher Nickname
# 2                                       Publisher URL
# 3                                         Publisher @
# 4                                        Publish Time
# 5                                          Post Likes
# 6                                         Description
# 7                        Number of 1st level comments
# 8                        Number of 2nd level comments
# 9   Total Comments (actual, in this list, rendered...
# 10  Total Comments (which TikTok tells you; it's t...
# 11                                         Difference
# 12                                Comment Number (ID)
# 13                                                  1
# 14                                                  2
# 15                                                  3
# 16                                                  4
# 17                                                  5
# 18                                                  6
# 19                                                  7
# 20                                                  8
# 21                                                  9
# 22                                                 10
# 23                                                 11
# 24                                                 12
# 25                                                 13
# 26                                                 14
# 27                                                 15
# 28                                                 16
# 29                                                 17
# 30                                                 18
# 31                                                 19
# 32                                                 20
# 33                                                 21
# 34                                                 22
# 35                                                 23
# 36                                                 24
# 37                                                 25
#
#    Tue Mar 22 2022 20:38:24 GMT+0800 (Singapore Standard Time)  \
# 0   https://www.tiktok.com/@hugo.nerman/video/6871...
# 1                                         Hugo Nerman
# 2                 https://www.tiktok.com/@hugo.nerman
# 3                                         hugo.nerman
# 4                                           11-9-2020
# 5                                                2666
# 6   First TikTok, don’t let it flop. #cars #racing...
# 7                                                  19
# 8                                                  11
# 9                                                  30
# 10                                                 35
# 11                                                  5
# 12                                           Nickname
# 13                                                  a
# 14                                     Lasse Lösgodis
# 15                              Hugo Nerman · Creator
# 16                                             Angelo
# 17                                     Harrison Duske
# 18                              Hugo Nerman · Creator
# 19                                     Harrison Duske
# 20                              Hugo Nerman · Creator
# 21                                              Will.
# 22                                     CocoTheCoconut
# 23                                                  .
# 24                              Hugo Nerman · Creator
# 25                                     Officialvilboo
# 26                            ✊ Respect all drivers ✊
# 27                                        connoraiken
# 28                                            PhernTv
# 29                                             Felkan
# 30                                       InteNils_iaf
# 31                                       Maday García
# 32                                    Jen jeidnlapxkn
# 33                                   Apple User353698
# 34                                  Inta thoris reee?
# 35                                           f1 hayat
# 36                                            Rithvik
# 37                                sebastianhedinovich
#
#                 Unnamed: 2           Unnamed: 3  \
# 0                      NaN                  NaN
# 1                      NaN                  NaN
# 2                      NaN                  NaN
# 3                      NaN                  NaN
# 4                      NaN                  NaN
# 5                      NaN                  NaN
# 6                      NaN                  NaN
# 7                      NaN                  NaN
# 8                      NaN                  NaN
# 9                      NaN                  NaN
# 10                     NaN                  NaN
# 11                     NaN                  NaN
# 12                  User @             User URL
# 13                 stl.mbl  https://example.com
# 14         _lasselosgodis_  https://example.com
# 15             hugo.nerman  https://example.com
# 16          the_backstaber  https://example.com
# 17            harrisonnn.d  https://example.com
# 18             hugo.nerman  https://example.com
# 19            harrisonnn.d  https://example.com
# 20             hugo.nerman  https://example.com
# 21                will.o88  https://example.com
# 22           fluffydogcoco  https://example.com
# 23          albin.wahlberg  https://example.com
# 24             hugo.nerman  https://example.com
# 25          officialvilboo  https://example.com
# 26            lukasstrand_  https://example.com
# 27            connoraiken1  https://example.com
# 28                 pherntv  https://example.com
# 29          fireballfelkan  https://example.com
# 30          gregerbergfors  https://example.com
# 31          madaygarcia.02  https://example.com
# 32               zkxoebroa  https://example.com
# 33  yurrrrrrrrrrrrrrrrrrr1  https://example.com
# 34           eshitipotesre  https://example.com
# 35                f1.hayat  https://example.com
# 36            retadrithvik  https://example.com
# 37              hedinsebbe  https://example.com
#
#                                            Unnamed: 4  Unnamed: 5 Unnamed: 6  \
# 0                                                 NaN         NaN        NaN
# 1                                                 NaN         NaN        NaN
# 2                                                 NaN         NaN        NaN
# 3                                                 NaN         NaN        NaN
# 4                                                 NaN         NaN        NaN
# 5                                                 NaN         NaN        NaN
# 6                                                 NaN         NaN        NaN
# 7                                                 NaN         NaN        NaN
# 8                                                 NaN         NaN        NaN
# 9                                                 NaN         NaN        NaN
# 10                                                NaN         NaN        NaN
# 11                                                NaN         NaN        NaN
# 12                                       Comment Text        Time      Likes
# 13                                          practice*   15-9-2020          7
# 14  What is that circuit called that you play in t...   15-9-2020          6
# 15                                 Spa francorchamps👌   15-9-2020         12
# 16                            Rly that’s your train 😂  29-10-2020          2
# 17                        A bit to much entry curb😅😅😅  31-10-2020          2
# 18        Oh you should see how much we use irl then😅  31-10-2020          5
# 19                                                Wym  31-10-2020          0
# 20            We’re as close to the grass as possible  31-10-2020          1
# 21                                Spa around oh rouge   7-11-2020          1
# 22  Would you say it's entertaining like playing a...  31-10-2020          0
# 23              Are you driving on SPA irl in a race?  29-10-2020          0
# 24             Yeah, I did one a couple of weeks back  31-10-2020          0
# 25                                     Manufactori ❤️   16-9-2020          0
# 26              Spa is my favorite track in formula 1   4-12-2020          0
# 27                Look at the date this is posted 😳😳😳  14-11-2020          0
# 28  How well do u think iracing compares to ur act...   5-11-2020          0
# 29  Vänta vänta träntar du på ACC? Är det så reali...   15-9-2020          3
# 30                                        Vad är acc?  28-10-2020          0
# 31                                nueva seguidoraa🥰🥰🥺    4-1-2021          0
# 32    The gt3 cup is the most dificult car on iracing   7-11-2020          0
# 33    why down shift in eu rouge? supposed to be flat   24-9-2020          0
# 34          if u buy me a simulator i will follow you   15-9-2020          1
# 35                    Do you race with ayhancan güven   7-11-2020          0
# 36  We’re you flat out through eau rouge or am I t...  30-10-2020          0
# 37                                    bosön simulator   15-9-2020          1
#
#                                            Unnamed: 7            Unnamed: 8  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                   NaN
# 2                                                 NaN                   NaN
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# 5                                                 NaN                   NaN
# 6                                                 NaN                   NaN
# 7                                                 NaN                   NaN
# 8                                                 NaN                   NaN
# 9                                                 NaN                   NaN
# 10                                                NaN                   NaN
# 11                                                NaN                   NaN
# 12                                Profile Picture URL  Is 2nd Level Comment
# 13  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                    No
# 14  https://p16-sign-va.tiktokcdn.com/musically-ma...                    No
# 15  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                   Yes
# 16  https://p16-sign-va.tiktokcdn.com/musically-ma...                    No
# 17  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                    No
# 18  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                   Yes
# 19  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                   Yes
# 20  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                   Yes
# 21  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                    No
# 22  https://p16-sign-va.tiktokcdn.com/musically-ma...                    No
# 23  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                    No
# 24  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                   Yes
# 25  https://p16-sign-va.tiktokcdn.com/musically-ma...                    No
# 26  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                    No
# 27  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                    No
# 28  https://p16-sign-va.tiktokcdn.com/musically-ma...                    No
# 29  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                    No
# 30  https://p16-sign-va.tiktokcdn.com/musically-ma...                   Yes
# 31  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                    No
# 32  https://p16-sign-sg.tiktokcdn.com/aweme/100x10...                    No
# 33  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                    No
# 34  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                    No
# 35  https://p16-sign-sg.tiktokcdn.com/aweme/100x10...                    No
# 36  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...                    No
# 37  https://p16-sign-va.tiktokcdn.com/musically-ma...                    No
#
#          Unnamed: 9        Unnamed: 10
# 0               NaN                NaN
# 1               NaN                NaN
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN
# 5               NaN                NaN
# 6               NaN                NaN
# 7               NaN                NaN
# 8               NaN                NaN
# 9               NaN                NaN
# 10              NaN                NaN
# 11              NaN                NaN
# 12       Replied To  Number of replies
# 13              ---                  0
# 14              ---                  1
# 15  _lasselosgodis_                ---
# 16              ---                  0
# 17              ---                  3
# 18     harrisonnn.d                ---
# 19     harrisonnn.d                ---
# 20     harrisonnn.d                ---
# 21              ---                  0
# 22              ---                  0
# 23              ---                  1
# 24   albin.wahlberg                ---
# 25              ---                  0
# 26              ---                  0
# 27              ---                  0
# 28              ---                  0
# 29              ---                  1
# 30   fireballfelkan                ---
# 31              ---                  0
# 32              ---                  0
# 33              ---                  0
# 34              ---                  0
# 35              ---                  0
# 36              ---                  0
# 37              ---                  0

# %% [markdown]
# #### 3. Reading each worksheet into a dataframe and storing inside an array

# %%
frames = []
#Looping through each worksheet and selecting only four columns
for i in range(len(main_df.sheet_names)):
    temp_variable = pd.DataFrame(main_df.parse(sheet_name = main_df.sheet_names[i]),columns=['Unnamed: 2','Unnamed: 6','Unnamed: 8','Unnamed: 10'])
    #Renaming the columns with proper names
    temp_variable.rename(columns = {'Unnamed: 2':'Username', 'Unnamed: 6':'No_of_likes', 'Unnamed: 8':'Second_Level_Comment', 'Unnamed: 10':'No_of_replies'}, inplace = True)
    frames.append(temp_variable)

# %%
#Example of data in one of the worksheets in a 2d format
frames[0]
# Out:
#                   Username No_of_likes  Second_Level_Comment  \
# 0                      NaN         NaN                   NaN
# 1                      NaN         NaN                   NaN
# 2                      NaN         NaN                   NaN
# 3                      NaN         NaN                   NaN
# 4                      NaN         NaN                   NaN
# 5                      NaN         NaN                   NaN
# 6                      NaN         NaN                   NaN
# 7                      NaN         NaN                   NaN
# 8                      NaN         NaN                   NaN
# 9                      NaN         NaN                   NaN
# 10                     NaN         NaN                   NaN
# 11                     NaN         NaN                   NaN
# 12                  User @       Likes  Is 2nd Level Comment
# 13                 stl.mbl           7                    No
# 14         _lasselosgodis_           6                    No
# 15             hugo.nerman          12                   Yes
# 16          the_backstaber           2                    No
# 17            harrisonnn.d           2                    No
# 18             hugo.nerman           5                   Yes
# 19            harrisonnn.d           0                   Yes
# 20             hugo.nerman           1                   Yes
# 21                will.o88           1                    No
# 22           fluffydogcoco           0                    No
# 23          albin.wahlberg           0                    No
# 24             hugo.nerman           0                   Yes
# 25          officialvilboo           0                    No
# 26            lukasstrand_           0                    No
# 27            connoraiken1           0                    No
# 28                 pherntv           0                    No
# 29          fireballfelkan           3                    No
# 30          gregerbergfors           0                   Yes
# 31          madaygarcia.02           0                    No
# 32               zkxoebroa           0                    No
# 33  yurrrrrrrrrrrrrrrrrrr1           0                    No
# 34           eshitipotesre           1                    No
# 35                f1.hayat           0                    No
# 36            retadrithvik           0                    No
# 37              hedinsebbe           1                    No
#
#         No_of_replies
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12  Number of replies
# 13                  0
# 14                  1
# 15                ---
# 16                  0
# 17                  3
# 18                ---
# 19                ---
# 20                ---
# 21                  0
# 22                  0
# 23                  1
# 24                ---
# 25                  0
# 26                  0
# 27                  0
# 28                  0
# 29                  1
# 30                ---
# 31                  0
# 32                  0
# 33                  0
# 34                  0
# 35                  0
# 36                  0
# 37                  0

# %% [markdown]
# #### 4. Combining all worksheets into one dataframe

# %%
combined_df = pd.concat(frames, join="inner", sort=False)
combined_df
# Out:
#            Username No_of_likes Second_Level_Comment No_of_replies
# 0               NaN         NaN                  NaN           NaN
# 1               NaN         NaN                  NaN           NaN
# 2               NaN         NaN                  NaN           NaN
# 3               NaN         NaN                  NaN           NaN
# 4               NaN         NaN                  NaN           NaN
# ..              ...         ...                  ...           ...
# 531      thembhakau           0                   No             0
# 532  eoinmcgowan_11           1                   No             0
# 533  antony.dimauro           1                   No             0
# 534     doggochoppa           0                   No             0
# 535       l.brown43           0                   No             0
#
# [25128 rows x 4 columns]

# %% [markdown]
# #### 5.  Removing empty rows and old headers

# %%
#Removing rows with no values in Username column
combined_df.dropna(subset=['Username'], inplace=True)

#Removing rows with 'User @' in Username column
unique_df = combined_df[combined_df.Username != 'User @']

#unique_df1 = unique_df[unique_df.Second_Level_Comment != 'Yes']

unique_df
# Out:
#             Username No_of_likes Second_Level_Comment No_of_replies
# 13           stl.mbl           7                   No             0
# 14   _lasselosgodis_           6                   No             1
# 15       hugo.nerman          12                  Yes           ---
# 16    the_backstaber           2                   No             0
# 17      harrisonnn.d           2                   No             3
# ..               ...         ...                  ...           ...
# 531       thembhakau           0                   No             0
# 532   eoinmcgowan_11           1                   No             0
# 533   antony.dimauro           1                   No             0
# 534      doggochoppa           0                   No             0
# 535        l.brown43           0                   No             0
#
# [22364 rows x 4 columns]

# %% [markdown]
# #### 6.  Removing duplicated Usernames and accumulating No_of_Likes

# %%
#Extracting duplicates and then grouping them together
duplicates = pd.concat(g for _, g in unique_df.groupby('Username') if len(g) > 1)
duplicates

#Accumulating No_of_Likes
...
# Out:
# Ellipsis

# %%
duplicates['No_of_likes'] = duplicates['No_of_likes'].astype(int)
duplicates['Total_likes'] = duplicates.groupby(['Username'])['No_of_likes'].transform('sum')

# %%
temp_dict = {}

for index, row in duplicates.iterrows():
  if row['Username'] not in temp_dict:
    temp_dict[row['Username']] = row['Second_Level_Comment']
  elif (row['Username'] not in temp_dict) and (temp_dict[row['Username']] != "No"):
    temp_dict[row['Username']] = row['Second_Level_Comment']

for k,v in temp_dict.items():
  if v == 'Yes':
    temp_dict[k] = 2
  else:
    temp_dict[k] = 1

# duplicates = duplicates.assign(degree_level = temp_dict[duplicates['Second_Level_Comment']])
duplicates['degree_level'] = duplicates.apply(
    lambda row: temp_dict[row.Username], axis=1)

duplicates
# Out:
#                    Username  No_of_likes Second_Level_Comment No_of_replies  \
# 18                    ..ipe            0                  Yes           ---
# 17                    ..ipe            4                   No             1
# 272                   ..ipe            0                   No             0
# 27   .ayayayayayayayayayaya            1                  Yes           ---
# 25   .ayayayayayayayayayaya            2                  Yes           ---
# ..                      ...          ...                  ...           ...
# 14                  zschulz            3                  Yes           ---
# 78                  zvenzon            0                   No             0
# 22                  zvenzon            4                   No             0
# 40                  zzz_364            0                   No             0
# 73                  zzz_364            0                   No             0
#
#      Total_likes  degree_level
# 18             4             2
# 17             4             2
# 272            4             2
# 27             3             2
# 25             3             2
# ..           ...           ...
# 14             4             1
# 78             4             1
# 22             4             1
# 40             0             1
# 73             0             1
#
# [7646 rows x 6 columns]

# %%
new_df = duplicates.drop_duplicates(subset=['Username'])
new_df
# Out:
#                    Username  No_of_likes Second_Level_Comment No_of_replies  \
# 18                    ..ipe            0                  Yes           ---
# 27   .ayayayayayayayayayaya            1                  Yes           ---
# 16                 .davoman            4                  Yes           ---
# 51              .deannaaa.x            1                   No             0
# 574               .dropcake            0                   No             2
# ..                      ...          ...                  ...           ...
# 24              zoeyeracing            6                   No             0
# 58                    zs1kr            0                   No             0
# 124                 zschulz            1                   No             0
# 78                  zvenzon            0                   No             0
# 40                  zzz_364            0                   No             0
#
#      Total_likes  degree_level
# 18             4             2
# 27             3             2
# 16             9             2
# 51             2             1
# 574            0             1
# ..           ...           ...
# 24           115             1
# 58             0             1
# 124            4             1
# 78             4             1
# 40             0             1
#
# [2312 rows x 6 columns]

# %%
#Drops all duplicates
unique_df.sort_values("Username", inplace = True)
unique_df.drop_duplicates(subset ="Username",keep = False, inplace = True)
# Out:
# C:\Users\rusyd\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
unique_df['Total_likes'] = unique_df.groupby(['Username'])['No_of_likes'].transform('sum')
unique_df
# Out:
# C:\Users\rusyd\AppData\Local\Temp/ipykernel_3380/3303715100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_df['Total_likes'] = unique_df.groupby(['Username'])['No_of_likes'].transform('sum')
#             Username No_of_likes Second_Level_Comment No_of_replies  \
# 183      .......owen           0                   No             0
# 75      ......nahman           0                   No             0
# 36          ....drip           3                  Yes           ---
# 13           ..auzzy           8                   No             0
# 97   ..cashmoneybaby           0                   No             0
# ..               ...         ...                  ...           ...
# 65            zyjami           0                   No             0
# 198            zyruz           0                   No             0
# 257        zyusuf322           0                   No             0
# 284          zzz_zad           1                  Yes           ---
# 73        zzzavitaev          33                  Yes           ---
#
#     Total_likes
# 183           0
# 75            0
# 36            3
# 13            8
# 97            0
# ..          ...
# 65            0
# 198           0
# 257           0
# 284           1
# 73           33
#
# [14718 rows x 5 columns]

# %%
temp_dict = {}

for index, row in unique_df.iterrows():
  if row['Username'] not in temp_dict:
    temp_dict[row['Username']] = row['Second_Level_Comment']
  elif (row['Username'] not in temp_dict) and (temp_dict[row['Username']] != "No"):
    temp_dict[row['Username']] = row['Second_Level_Comment']

for k,v in temp_dict.items():
  if v == 'Yes':
    temp_dict[k] = 2
  else:
    temp_dict[k] = 1

# duplicates = duplicates.assign(degree_level = temp_dict[duplicates['Second_Level_Comment']])
unique_df['degree_level'] = unique_df.apply(
    lambda row: temp_dict[row.Username], axis=1)

unique_df
# Out:
# C:\Users\rusyd\AppData\Local\Temp/ipykernel_3380/2342311451.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_df['degree_level'] = unique_df.apply(
#             Username No_of_likes Second_Level_Comment No_of_replies  \
# 183      .......owen           0                   No             0
# 75      ......nahman           0                   No             0
# 36          ....drip           3                  Yes           ---
# 13           ..auzzy           8                   No             0
# 97   ..cashmoneybaby           0                   No             0
# ..               ...         ...                  ...           ...
# 65            zyjami           0                   No             0
# 198            zyruz           0                   No             0
# 257        zyusuf322           0                   No             0
# 284          zzz_zad           1                  Yes           ---
# 73        zzzavitaev          33                  Yes           ---
#
#     Total_likes  degree_level
# 183           0             1
# 75            0             1
# 36            3             2
# 13            8             1
# 97            0             1
# ..          ...           ...
# 65            0             1
# 198           0             1
# 257           0             1
# 284           1             2
# 73           33             2
#
# [14718 rows x 6 columns]

# %%
#Adding them back to the original dataframe
frames = [unique_df, new_df]
  
result = pd.concat(frames)
result
# Out:
#             Username No_of_likes Second_Level_Comment No_of_replies  \
# 183      .......owen           0                   No             0
# 75      ......nahman           0                   No             0
# 36          ....drip           3                  Yes           ---
# 13           ..auzzy           8                   No             0
# 97   ..cashmoneybaby           0                   No             0
# ..               ...         ...                  ...           ...
# 24       zoeyeracing           6                   No             0
# 58             zs1kr           0                   No             0
# 124          zschulz           1                   No             0
# 78           zvenzon           0                   No             0
# 40           zzz_364           0                   No             0
#
#     Total_likes  degree_level
# 183           0             1
# 75            0             1
# 36            3             2
# 13            8             1
# 97            0             1
# ..          ...           ...
# 24          115             1
# 58            0             1
# 124           4             1
# 78            4             1
# 40            0             1
#
# [17030 rows x 6 columns]

# %%
# result.drop("No_of_likes", axis=1, inplace=True)
result.drop("Second_Level_Comment", axis=1, inplace=True)

# %%
result
# Out:
#             Username No_of_likes No_of_replies Total_likes  degree_level
# 183      .......owen           0             0           0             1
# 75      ......nahman           0             0           0             1
# 36          ....drip           3           ---           3             2
# 13           ..auzzy           8             0           8             1
# 97   ..cashmoneybaby           0             0           0             1
# ..               ...         ...           ...         ...           ...
# 24       zoeyeracing           6             0         115             1
# 58             zs1kr           0             0           0             1
# 124          zschulz           1             0           4             1
# 78           zvenzon           0             0           4             1
# 40           zzz_364           0             0           0             1
#
# [17030 rows x 5 columns]

# %%
result.to_csv('network_result.csv', index=False)

# %%
import sys, time

def progress(v):
    v = str(v)
    sys.stdout.flush()
    sys.stdout.write('\r')
    sys.stdout.flush()
    sys.stdout.write(v)

# %%
f = open("output.gml", "w")
#helpers
s = " "
ss = s+s
sss = s+s+s
ssss = s+s+s+s
nl = "\n"

#loop helpers
added = []
ind = 0

#Root node
f.write("graph"+nl)
f.write("["+nl)

#Write an edge
def write_edge(r):
    f.write( ss + "edge" + nl)
    f.write( ss + "[" + nl)
    f.write( ssss + "source" + s + '"' + str(r['AUTHOR_ID']) + '"' + nl)
    f.write( ssss + "target" + s + '"' + str(r['CO-AUTHOR_ID']) + '"' + nl)
    f.write( ssss + "value" + s + str(r['NO_OF_BOOKS']) + '"' + nl)
    f.write( ss + "]"+ nl)

#Write a node
def write_node(r):
    f.write( ss + "node" + nl)
    f.write( ss + "[" + nl)
    f.write( ssss + "id" + s + '"' + str(ind) + '"' + nl)
    f.write( ssss + "label" + s + '"' + str(r['Username']) + '"' + nl)
    f.write( ssss + "value" + s + '"' + str(r['Total_likes']) + '"' + nl)
    f.write( ss + "]"+ nl)

#Generate nodes
for i, r in result.iterrows():
    #increment, as index not reliable
    ind += 1
    #Check for duplicates
    if (r['Username'] not in added):
        #Add to list
        added.append(r['Username'])
        write_node(r)
    #print the progress    
    progress(ind)

print(nl+"Printing nodes over")

#flush index
ind = 0    
#Generate edges    
for i, r in df.iterrows():
    #increment, as index not reliable
    ind += 1
    if(r['AUTHOR_ID'] < r['CO-AUTHOR_ID']):
        write_edge(r)
    #print the progress            
    progress(ind)

print(nl+"Printing nodes and edges over")

#closing node
f.write("]"+nl)
f.close()
# Out:
# 1500
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 3358
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 5213
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 7168
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 8964
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 10887
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 12756
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 14630
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 16364
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#unique_df.sort_values("Username", inplace=True)
#unique_df.drop_duplicates(subset = ["Username"],keep = 'first')

#unique_df
# Out:
# C:\Users\rusyd\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#             Username No_of_likes Second_Level_Comment No_of_replies
# 183      .......owen           0                   No             0
# 75      ......nahman           0                   No             0
# 36          ....drip           3                  Yes           ---
# 13           ..auzzy           8                   No             0
# 97   ..cashmoneybaby           0                   No             0
# ..               ...         ...                  ...           ...
# 257        zyusuf322           0                   No             0
# 40           zzz_364           0                   No             0
# 73           zzz_364           0                   No             0
# 284          zzz_zad           1                  Yes           ---
# 73        zzzavitaev          33                  Yes           ---
#
# [22364 rows x 4 columns]
